# %% [markdown]
# ## Flow poset

# %%
# load package from Morse_Theory
# !sage --preparse Morse_Theory/Flow.sage
# !mv Morse_Theory/Flow.sage.py Morse_Theory/Flow.py

from Morse_Theory.Flow import *

# %%
# Example usage with a sample poset X
X = Poset({'w': ['x', 'z'], 'y': ['x', 'z'], 'x': ['t', 'b'], 'z': ['t', 'b']})

X.show()
# Out:
# Graphics object consisting of 15 graphics primitives

# %%
# Compute the entrance path poset for the interval [w, t]
entrance_poset = entrance_path_poset(X, 'w', 't')
entrance_poset.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
P = flow_poset(X, [('y','x'), ('z','b')])
# Out:
# Processing matching pair: (y, x)
# Processing matching pair: (z, b)

# %%
P[('w','t')].show(figsize=[6,6])
# Out:
# Graphics object consisting of 17 graphics primitives
