# %%
# load package from Morse_Theory
# !sage --preparse Morse_Theory/Strong.sage
# !mv Morse_Theory/Strong.sage.py Morse_Theory/Strong.py

from Morse_Theory.Strong import *

# %%
K = simplicial_complexes.Torus()
#K = simplicial_complexes.KleinBottle()
#K = simplicial_complexes.Sphere(3)
#K = simplicial_complexes.RudinBall()
#K = simplicial_complexes.ZieglerBall()
#K = simplicial_complexes.PoincareHomologyThreeSphere()

# %%
K.facets()
# Out:
# {(0, 3, 4), (0, 4, 6), (1, 2, 4), (1, 3, 6), (0, 1, 2), (0, 2, 6), (2, 4, 5), (2, 3, 6), (2, 3, 5), (0, 1, 5), (0, 3, 5), (4, 5, 6), (1, 3, 4), (1, 5, 6)}

# %%
X = K.face_poset()
len(X)
# Out:
# 42

# %%
G = K.graph()
G.plot(save_pos=True)
# Out:
# Graphics object consisting of 29 graphics primitives

# %%
X = K.face_poset()

# %%
X.show()
# Out:
# Graphics object consisting of 127 graphics primitives

# %%
len(X)
# Out:
# 42

# %%
Y, critical_cells, matching = strong_Morse_reduction(X)
core = Morse_core(X, critical_cells, matching)
# Out:
# No dominated vertex found, removing critical vertex: (6,)
# No dominated vertex found, removing critical vertex: (5,)
# No dominated vertex found, removing critical vertex: (4,)
# No dominated vertex found, removing critical vertex: (3,)
# (1,) dominates (2,)
# (0,) dominates (1,)
# No dominated vertex found, removing critical vertex: (0,)

# %%
len(core)
# Out:
# 36

# %%
core.show()
# Out:
# Graphics object consisting of 109 graphics primitives

# %%
core.order_complex().homology()
# Out:
# {0: 0, 1: Z x Z, 2: Z}

# %%
core.order_complex().fundamental_group()
# Out:
# Finitely presented group < e0, e1 | e0^-1*e1^-1*e0*e1 >
